# %% [markdown]
# # **Day-ahead Stock Forecasting**
#
# #### Input - 15 mins candle data
# #### Output - Forcast of 1 day of 15 mins close price

# %% [markdown]
# Special Notes:
#  - Don't open CSV file and change dateformat, it will change the format entirely and cause problem in code
#  - Output of Model changed if we dont delete NaN values (I saw that when comparing jupyter file with normal python file matching)

# %% [markdown]
# ## Define stock for which ML model needs to be prepared

# %%
#stock = "HDFCBANK"


# Get data from Python file--------------
import json

# Load the arguments
with open('arguments.json', 'r') as fid:
    arguments = json.load(fid)

stock = arguments['ticker']

print(stock)
# Out:
# SUNPHARMA

# %%
from datetime import datetime, timedelta
from pandas.tseries.offsets import DateOffset
import math
import pickle # Saving the final model
import time
import datetime as dt

##############
# Dependencies
##############
import json
import requests
import numpy as np
import pandas as pd
import os, time, math
from datetime import *
os.environ['TZ'] = 'Asia/Calcutta'
from sqlalchemy import create_engine
from scipy.signal import savgol_filter
pd.options.mode.chained_assignment = None





##################
# Visualizations
#################
import seaborn as sns
#import plotly.offline
#import cufflinks as cf
import matplotlib.pyplot as plt
from matplotlib import rc, rcParams



##################
# Display Changes
##################
# cf.go_offline()
# %matplotlib inline
rc('axes', linewidth=2)
rc('font', weight='bold')
sns.set_style('whitegrid')
#pd.set_option('max_rows',2000)
#pd.set_option('max_columns',255) 
rcParams['figure.figsize'] = 15,5
#cf.set_config_file(offline=False, world_readable=True)


##############
# Modeling
##############
# import xgboost as xgb
# from xgboost import plot_importance
from sklearn import preprocessing, svm
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, RobustScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")
#warnings.filterwarnings("ignore", category=UserWarning)
#warnings.filterwarnings("ignore", category=FutureWarning)
#warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# ##################
# # Display Changes
# ##################
# from matplotlib import rc, rcParams
# pd.options.mode.chained_assignment = None
# # cf.go_offline()
# %matplotlib inline
# rc('axes', linewidth=2)
# #rc('font', weight='bold')

# #pd.set_option('max_rows', 1000)
# pd.set_option('display.max_rows', None)
# pd.set_option('max_columns', 255)
# # Useful line of code to set the display option so we could see all the columns in pd dataframe
# #pd.set_option('display.max_columns', None)

# #rcParams['figure.figsize'] = 8,3
# # cf.set_config_file(offline=False, world_readable=True)

# rc('xtick', labelsize=9) 
# rc('ytick', labelsize=9)
# #rc('axes', linewidth=2)
# rc('axes', titlesize=10)


# # Matplot Theme setting
# from matplotlib import cycler
# colors = cycler('color',
#                 ['#EE6666', '#3388BB', '#9988DD',
#                  '#EECC55', '#88BB44', '#FFBBBB'])
# rc('axes', facecolor='#E6E6E6', edgecolor='none', axisbelow=True, grid=True, prop_cycle=colors)
# rc('grid', color='w', linestyle='solid')
# rc('xtick', direction='out', color='black')
# rc('ytick', direction='out', color='black')
# rc('patch', edgecolor='#E6E6E6')
# rc('lines', linewidth=1)

# %%
# Seaborn
rc = {
    "axes.facecolor": "#FAEEE9",
    "figure.facecolor": "#FAEEE9",
    "axes.edgecolor": "#000000",
    "grid.color": "#EBEBE7",
    "font.family": "calibri",
    "axes.labelcolor": "#000000",
    "xtick.color": "#000000",
    "ytick.color": "#000000",
    "grid.alpha": 0.9
}
sns.set(rc=rc)
sns.set_context("notebook", font_scale=0.9, rc={"lines.linewidth": 1})


#sns.set_style('whitegrid')

# %% [markdown]
# ## Analysis

# %%
# I have make the function for Doing quick basic analysis as per given DataFrame

def analysis(df):
    
    print('#############################################################')
    print(f'Shape of DF = {df.shape}\n')
    print('--------------------------------------------------')
    print(f'First 5 rows are as following \n {df.head()} \n')
    print('--------------------------------------------------')
    print(f'Basic info as following \n {df.info()} \n')
    print('--------------------------------------------------')
  
    if 'datetime' in df.columns:
        print(f"\n We have data from {pd.to_datetime(df['datetime']).min()}")
        print(f" We have data till {pd.to_datetime(df['datetime']).max()}")
    print('--------------------------------------------------')
    print(f'\n Basic description as following \n')
    print(df.describe())
    print('--------------------------------------------------')
    print(f'\n Missing values are as following \n')
    print(df.isnull().sum())
    print('##############################################################')

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# folder_path = '/content/drive/MyDrive/Climate_Connect/IEX/01_Data_Tuesday_Forecast'

# %%
# As its difficult to upload files again and again, so I change code to access drive files. 

#df = pd.read_parquet('./Data/historical_load_data.parquet')
#df = pd.read_excel(f'{folder_path}/DAM_multivariate_data.xlsx')


df = pd.read_csv(f'01_Data\data_{stock}.csv')
#analysis(df)

# %%
print(f"\n We have data from {pd.to_datetime(df['datetime']).min()}")
print(f" We have data till {pd.to_datetime(df['datetime']).max()}")
# Out:
#  We have data from 2016-10-03 09:15:00
#  We have data till 2023-11-21 15:15:00

# %%
pd.to_datetime(df['datetime']).min().month
# Out:
# 10

# %%
#df.tz_convert('UTC')
#d = pd.to_datetime(df['datetime'],format='%m-%d-%Y %H:%M:%S').min()
#d.month

# %%
# DataType convertion

df['datetime'] = pd.to_datetime(df['datetime'])
df['date'] = df['datetime'].dt.date

# %%
# Missing Data checking

df = df.sort_values('datetime').copy()
print('Missing Value summary')
print(f'{df.isnull().sum()} \n')

# Missing and Duplicate values checking
print('If there is any missing and duplicate values')
df.date.value_counts()[df.date.value_counts() != 7] # 7 As we have one hour data

# %age missing values
# df.isnull().sum()/df.shape[0]*100
# Out:
# Missing Value summary
# datetime    0
# open        0
# high        0
# low         0
# close       0
# volume      0
# date        0
# dtype: int64
#
# If there is any missing and duplicate values
# 2020-12-08    8
# 2017-04-28    8
# 2021-02-24    5
# 2017-07-10    4
# 2019-10-27    3
# 2018-11-07    2
# 2017-10-19    2
# 2020-11-14    2
# 2021-11-04    2
# 2016-10-30    1
# 2023-11-12    1
# 2022-10-24    1
# Name: date, dtype: int64

# %%
# Drop the Duplicated values
df.drop_duplicates(['datetime'], keep='first', inplace=True)

# %%
## Plot as per original data on daily basis
def original_plot(df, feature):
    plt.figure(figsize=(12,5))
    #df.set_index('datetime').resample('D')[feature].mean().plot()
    df.set_index('datetime')[feature].plot()
    plt.xlim([df.datetime.min(), df.datetime.max()])
    plt.ylabel(feature)
    plt.title(f"{feature} Data on daily basis")
    plt.tight_layout()

# %%
original_plot(df, 'close')

# %% [markdown]
# ### Holiday Data - Step not performed as holiday data is very less

# %% [markdown]
# ## DataFrame Preperation

# %%
print(pd.to_datetime(df['datetime']).dt.date.min())
print(pd.to_datetime(df['datetime']).dt.date.max())
print(pd.to_datetime(df['datetime']).dt.date.max() + timedelta(days=1)) # today + 1 day(forecast date)
# Out:
# 2016-10-03
# 2023-11-21
# 2023-11-22

# %%
"""
# NO NEED to do as below due to the following:
 - We have many muhuraat days
 - We have holidays
 
"""


# # Prepare FInal Daraframe to avoid any missing time block

# #start_date = '2020-07-01'
# #end_date = '2023-02-17' # today + 1 day(forecast date)

# start_date = pd.to_datetime(df['datetime']).dt.date.min() # Data is available from 
# end_date = pd.to_datetime(df['datetime']).dt.date.max() + timedelta(days=1) # Data available till



# z = pd.DataFrame(pd.date_range(start=start_date, end=end_date, freq='1H',closed='left'), columns=['datetime']) #inclusive in the newer version
# df = pd.merge(z, df, on='datetime', how='left').copy()

# df['date'] = df['datetime'].dt.date
# # Make column for Time Block here 
# df['tb'] = df['datetime'].apply(lambda x : ((x.hour*60 + x.minute)//60+1))

# print(df.shape)
# print(df.tail())
# print(f"\n Close data is missing for {df.close.isna().sum()} records")
# Out:
# '\n# NO NEED to do as below due to the following:\n - We have many muhuraat days\n - We have holidays\n \n'

# %%
# %age missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# datetime    0.0
# open        0.0
# high        0.0
# low         0.0
# close       0.0
# volume      0.0
# date        0.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['datetime', 'open', 'high', 'low', 'close', 'volume', 'date'], dtype='object')

# %% [markdown]
# ### Only retain "Close" & "Volume"

# %%
#drop_col = ['open', 'high', 'low', 'volume']
drop_col = ['open', 'high', 'low']
df = df.drop(drop_col, axis=1)

# %%
'''
Missing Values treatment
'''

## Interpolation Technique
# df['open'] = df['open'].interpolate()
# df['high'] = df['high'].interpolate()
# df['low'] = df['low'].interpolate()
df['close'] = df['close'].interpolate()
df['volume'] = df['volume'].interpolate()

df.isnull().sum()
# Out:
# datetime    0
# close       0
# volume      0
# date        0
# dtype: int64

# %%
# %age missing values
df.isnull().sum()/df.shape[0]*100
# Out:
# datetime    0.0
# close       0.0
# volume      0.0
# date        0.0
# dtype: float64

# %% [markdown]
# ## EDA

# %%
for x in [x for x in range(2016, 2023)]:
    df[df.datetime.dt.year==x].set_index('datetime').resample('D')['close'].mean().plot(label=x, figsize=(15,7))
    plt.ylim([10, df.close.quantile(0.99)])
    plt.legend(loc="lower left")

# %%
# To check if mcp_dam is normally distributed or not
import scipy.stats as stat
import pylab

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
sns.histplot(data=df,x='close', alpha=0.5, bins=20)

plt.subplot(1,2,2)
stat.probplot(df['close'],dist='norm',plot=pylab)
plt.show()

# %% [markdown]
# As curve is not following staright line, so close is not normally distributed.

# %%
## Checking zero or -ve mcp_dam values
df.loc[df['close']<=0, :]
# Out:
# Empty DataFrame
# Columns: [datetime, close, volume, date]
# Index: []

# %% [markdown]
# So we have few zero values, we need to replace all with NaN and later will interpolate to get values

# %%
df.loc[df['close']==0, 'close'] = np.nan
df.loc[df['volume']==0, 'volume'] = np.nan
## Interpolation Technique
df['close'] = df['close'].interpolate()
df['volume'] = df['volume'].interpolate()
df.isnull().sum()
# Out:
# datetime    0
# close       0
# volume      0
# date        0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
def gen_datetime_features(data):
    
    try:
        #Adding time based features
        print('Adding time based features...')
        data['date'] = data.datetime.dt.date   
        data['hour'] = data.datetime.dt.hour + 1      # Categorical 24
        data['dom' ] = data.datetime.dt.day       # Categorical 30/31    
        data['month'] = data.datetime.dt.month        # Categorical 12
        data['year']=data.datetime.dt.year            # Categorical 12
        data['dow'] = data.datetime.dt.dayofweek      # Categorical 7
        data['doy'] = data.datetime.dt.dayofyear      # Categorical 365/366
        data['woy'] = data.datetime.dt.week # Categorical 52
    
        data['week_number'] = data['datetime'].apply(lambda time: time.strftime("%V"))
        # Above is Object DataType, so change to int
        data['week_number'] = data['week_number'].astype('int')
    
        # Friday
        data.loc[data.dow == 4, 'friday'] = 1
        data.loc[data.dow != 4, 'friday'] = 0   
    
    
#     # Covid
#     data.loc[data.year.isin([2020,2021,2022]),'covid'] = 1
#     data['covid'] = data['covid'].replace(np.nan, 0)
#     # Covid 1st wave
#     data.loc[(data.year==2020)&(data.month.isin([3,4,5,6,7,8,9])),'covid_first_wave'] = 1
#     data['covid_first_wave'] = data['covid_first_wave'].replace(np.nan, 0)
#     # Covid 2nd wave
#     data.loc[(data.year==2021)&(data.month.isin([3,4,5,6])),'covid_second_wave'] = 1
#     data['covid_second_wave'] = data['covid_second_wave'].replace(np.nan, 0)

        print(data.columns)
        return data
    except Exception as e:
        print("Error in adding time based features")



# Creating Cyclic Time Indicators

def cyclic(data,feature):
    import math
    data['norm'] = 2 * math.pi * data[f"{feature}"] / data[f"{feature}"].max()
    data[f"cos_{feature}"] = np.cos(data["norm"])
    data[f"sin_{feature}"] = np.sin(data["norm"])
    data.drop('norm',1,inplace=True)
    return data


def gen_cyclic_features(data):
    
    try:
        print('Adding Cyclic Time Indicators........')
        data = cyclic(data,'hour')
        data = cyclic(data,'dow')
        data = cyclic(data,'doy')
        return data
    except Exception as e:
        print("Error in adding Cyclic Time Indicators")





def gen_lag_features(data):
    try:
        # Encoding TS variables
        print('Adding TB Lag features...')
        variable_used = 'close'


        # As we have large data, so better we should drop NaN values
        data['lag1h'] = data[variable_used].shift(1*4)
        data['lag2h'] = data[variable_used].shift(2*4)
        data['lag4h'] = data[variable_used].shift(4*4)
        data['lag6h'] = data[variable_used].shift(6*4)
        data['lag12h'] = data[variable_used].shift(12*4)
        data['lag1d'] = data[variable_used].shift(24*4)
        data['lag2d'] = data[variable_used].shift(2*24*4)
        data['lag3d'] = data[variable_used].shift(3*24*4)
        data['lag4d'] = data[variable_used].shift(4*24*4)
        data['lag5d'] = data[variable_used].shift(5*24*4)
        data['lag6d'] = data[variable_used].shift(6*24*4)
        data['lag7d'] = data[variable_used].shift(7*24*4)
    


    # Exponential Moving Averages
        data['mcp_dam_ewm1h'] = data[variable_used].ewm(span = 1*4).mean()
        data['mcp_dam_ewm2h'] = data[variable_used].ewm(span = 2*4).mean()
        data['mcp_dam_ewm3h'] = data[variable_used].ewm(span = 3*4).mean()
        data['mcp_dam_ewm4h'] = data[variable_used].ewm(span = 4*4).mean()
        data['mcp_dam_ewm6h'] = data[variable_used].ewm(span = 6*4).mean()
        data['mcp_dam_ewm8h'] = data[variable_used].ewm(span = 8*4).mean()
        data['mcp_dam_ewm12h'] = data[variable_used].ewm(span = 12*4).mean()
        data['mcp_dam_ewm24h'] = data[variable_used].ewm(span = 24*4).mean()
    
    
    
    
    # Moving Averages
        for x in [4,8,12,24,48,96]:
            data[f'close_rolling_mean_{x}'] = data[variable_used].rolling(x,1).mean().shift()
            data[f'close_rolling_max_{x}'] = data[variable_used].rolling(x,1).max().shift()
            data[f'close_rolling_min_{x}'] = data[variable_used].rolling(x,1).min().shift()

    # Differences
    # As per analysis these features has least importance , so we will not use 
        data['ramp1'] = data[variable_used] - data[variable_used].shift(1)
        data['ramp2'] = data[variable_used].shift(1) - data[variable_used].shift(2)
        data['ramp3'] = data[variable_used].shift(2) - data[variable_used].shift(3)
        data['ramp4'] = data[variable_used].shift(3) - data[variable_used].shift(4)
    

#     # Taking Last 7 day same TB Mean, These features are super important
#     data['avg_mcp_dam_7d'] = (data['mcp_dam'] + data['mcp_dam'].shift(96) + data['mcp_dam'].shift(2*96) + data['mcp_dam'].shift(3*96)) + data['mcp_dam'].shift(4*96) + data['mcp_dam'].shift(5*96) + data['mcp_dam'].shift(6*96) / 7
#     data['avg_mcp_dam_9d'] = (data['avg_mcp_dam_7d']*7 + data['mcp_dam'].shift(7*96) + data['mcp_dam'].shift(8*96))/9
#     data['avg_mcp_dam_11d'] = (data['avg_mcp_dam_9d']*9 + data['mcp_dam'].shift(9*96) + data['mcp_dam'].shift(10*96))/11
#     data['avg_mcp_dam_13d'] = (data['avg_mcp_dam_11d']*11 + data['mcp_dam'].shift(11*96) + data['mcp_dam'].shift(12*96))/13
#     data['avg_mcp_dam_15d'] = (data['avg_mcp_dam_13d']*13 + data['mcp_dam'].shift(13*96) + data['mcp_dam'].shift(14*96))/15
#     data['avg_mcp_dam_17d'] = (data['avg_mcp_dam_15d']*15 + data['mcp_dam'].shift(15*96) + data['mcp_dam'].shift(16*96))/17
#     data['avg_mcp_dam_19d'] = (data['avg_mcp_dam_17d']*17 + data['mcp_dam'].shift(17*96) + data['mcp_dam'].shift(18*96))/19
#     data['avg_mcp_dam_21d'] = (data['avg_mcp_dam_19d']*19 + data['mcp_dam'].shift(19*96) + data['mcp_dam'].shift(20*96))/21
    
    
    
    
        print(data.columns)
        return data
    except Exception as e:
        print(f"Error in adding Lag based features--{e}")

# %%
df = gen_datetime_features(df).copy()
# Out:
# Adding time based features...
# Index(['datetime', 'close', 'volume', 'date', 'hour', 'dom', 'month', 'year',
#        'dow', 'doy', 'woy', 'week_number', 'friday'],
#       dtype='object')

# %% [markdown]
# ## Outliers checking - Not Done

# %% [markdown]
# ## Check the Trend, Seasonality & Residual

# %%
# Let's try decomposing the load data
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib as mpl
from pylab import rcParams
# Extra settings
seed = 42
np.random.seed(seed)
plt.style.use('bmh')


plt.figure(num=None, figsize=(50, 20), dpi=80, facecolor='w', edgecolor='k')
series = df[(df['datetime']>='2020-01-01') & (df['datetime']<'2022-01-01')].set_index(['datetime'])['close'].dropna()
result = seasonal_decompose(series, model='multiplicative',period=30)
result.plot()

# %% [markdown]
# Seasonality is present

# %%
from sklearn.linear_model import LinearRegression
fig = plt.figure(figsize=(15, 7))
layout = (3, 2)
pm_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
mv_ax = plt.subplot2grid(layout, (1, 0), colspan=2)
fit_ax = plt.subplot2grid(layout, (2, 0), colspan=2)

pm_ax.plot(result.trend)
pm_ax.set_title("Automatic decomposed trend")

mm = series.rolling(200).mean()
mv_ax.plot(mm)
mv_ax.set_title("Moving average 365 steps")

X = [i for i in range(0, len(series))]
X = np.reshape(X, (len(X), 1))
y = series.values
model = LinearRegression()
model.fit(X, y)
# calculate trend
trend = model.predict(X)
fit_ax.plot(trend)
fit_ax.set_title("Trend fitted by linear regression")

plt.tight_layout()

# %% [markdown]
# 1. Seasonality is present
# 2. Data is non-stationary

# %% [markdown]
# ## Check for non-stationarity

# %%
# Determing rolling statistics
rolmean = series.rolling(window=200).mean()
rolstd = series.rolling(window=200).std()

# Plot rolling statistics:
orig = plt.plot(series, label='Original')
mean = plt.plot(rolmean, color='red', label='Rolling Mean')
std = plt.plot(rolstd, color='black', label='Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %% [markdown]
# Mean and Standar deviation does not have a constant behaviour over the years, This proves us again a non-stationary series

# %% [markdown]
# ## Check ACF & PACF plots for autocorelation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
#series = df[(df['datetime']>='2020-01-01') & (df['datetime']<'2023-01-01')]['close'].dropna()
series = df['close'].dropna()
plot_acf(series, lags=12)
plot_pacf(series, lags=12)
#plot_pacf(series, lags=7)
plt.show()

# %% [markdown]
# We can see from the ACF curve that there is autocorrelation.
# As per PACF graph, lag - 1,2,3,4,5 are statistically significant,
# so we will include all in feature engineering.

# %%
## Save a copy of DataFrame for using later for different lagged Model for Multioutput
df_multi = df.copy()

# %% [markdown]
# ## Creating Features

# %%
data = df.copy()
data.head(2)
# Out:
#              datetime  close    volume        date  hour  dom  month  year  \
# 0 2016-10-03 09:15:00  642.1  217902.0  2016-10-03    10    3     10  2016
# 1 2016-10-03 10:15:00  643.5  202408.0  2016-10-03    11    3     10  2016
#
#    dow  doy  woy  week_number  friday
# 0    0  277   40           40     0.0
# 1    0  277   40           40     0.0

# %%
#data = radial_features(data).copy() # Have to install sklego
data = gen_cyclic_features(data).copy()
data = gen_lag_features(data).copy()
# Out:
# Adding Cyclic Time Indicators........
# Adding TB Lag features...
# Index(['datetime', 'close', 'volume', 'date', 'hour', 'dom', 'month', 'year',
#        'dow', 'doy', 'woy', 'week_number', 'friday', 'cos_hour', 'sin_hour',
#        'cos_dow', 'sin_dow', 'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h',
#        'lag6h', 'lag12h', 'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d',
#        'lag7d', 'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h',
#        'mcp_dam_ewm4h', 'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h',
#        'mcp_dam_ewm24h', 'close_rolling_mean_4', 'close_rolling_max_4',
#        'close_rolling_min_4', 'close_rolling_mean_8', 'close_rolling_max_8',
#        'close_rolling_min_8', 'close_rolling_mean_12', 'close_rolling_max_12',
#        'close_rolling_min_12', 'close_rolling_mean_24', 'close_rolling_max_24',
#        'close_rolling_min_24', 'close_rolling_mean_48', 'close_rolling_max_48',
#        'close_rolling_min_48', 'close_rolling_mean_96', 'close_rolling_max_96',
#        'close_rolling_min_96', 'ramp1', 'ramp2', 'ramp3', 'ramp4'],
#       dtype='object')

# %%
# Plotting how the Time Features look after getting a sin cos transformation
plt.figure(figsize=(10,5))
sns.scatterplot(x=data.sin_hour, y=data.cos_hour)
plt.show()

# %% [markdown]
# ## Shifting by Lag Time forecasting

# %%
target_ahead_timeblocks = 7  # Forecasting Lead Time

# %%
# Shifting of Data as per Forecasting Lead Time
def shift_variable_by_TB(data, target_ahead_timeblocks):
    
    data['ramp_close'] = data['close'] - data['close'].shift(target_ahead_timeblocks) # Creating one feature based on the forecast horizon
    data['ramp_volume'] = data['volume'] - data['volume'].shift(target_ahead_timeblocks)
    features = data.columns.tolist()
  # Creating target variable
    data['target'] = data['close'].shift(-target_ahead_timeblocks)
    return data

# %%
data = shift_variable_by_TB(data, target_ahead_timeblocks)

# %%
# Save DataFrame to new variable to make a check point
data_for_training = data.set_index('datetime').copy()
data_for_training.tail(10)
# Out:
#                        close     volume        date  hour  dom  month  year  \
# datetime
# 2023-11-20 13:15:00  1505.70  2436743.0  2023-11-20    14   20     11  2023
# 2023-11-20 14:15:00  1505.50  1715079.0  2023-11-20    15   20     11  2023
# 2023-11-20 15:15:00  1505.30   568800.0  2023-11-20    16   20     11  2023
# 2023-11-21 09:15:00  1516.35  2795587.0  2023-11-21    10   21     11  2023
# 2023-11-21 10:15:00  1520.95  1644687.0  2023-11-21    11   21     11  2023
# 2023-11-21 11:15:00  1519.30  1313458.0  2023-11-21    12   21     11  2023
# 2023-11-21 12:15:00  1514.65  1469270.0  2023-11-21    13   21     11  2023
# 2023-11-21 13:15:00  1516.85   896454.0  2023-11-21    14   21     11  2023
# 2023-11-21 14:15:00  1518.15  2361418.0  2023-11-21    15   21     11  2023
# 2023-11-21 15:15:00  1517.55  1223239.0  2023-11-21    16   21     11  2023
#
#                      dow  doy  woy  ...  close_rolling_mean_96  \
# datetime                            ...
# 2023-11-20 13:15:00    0  324   47  ...            1490.206771
# 2023-11-20 14:15:00    0  324   47  ...            1490.452083
# 2023-11-20 15:15:00    0  324   47  ...            1490.725521
# 2023-11-21 09:15:00    1  325   47  ...            1490.997396
# 2023-11-21 10:15:00    1  325   47  ...            1491.380729
# 2023-11-21 11:15:00    1  325   47  ...            1491.787500
# 2023-11-21 12:15:00    1  325   47  ...            1492.244271
# 2023-11-21 13:15:00    1  325   47  ...            1492.657292
# 2023-11-21 14:15:00    1  325   47  ...            1493.185938
# 2023-11-21 15:15:00    1  325   47  ...            1493.729167
#
#                      close_rolling_max_96  close_rolling_min_96  ramp1  ramp2  \
# datetime
# 2023-11-20 13:15:00               1515.95                1466.0   1.70   0.10
# 2023-11-20 14:15:00               1515.95                1466.0  -0.20   1.70
# 2023-11-20 15:15:00               1515.95                1466.0  -0.20  -0.20
# 2023-11-21 09:15:00               1515.95                1466.0  11.05  -0.20
# 2023-11-21 10:15:00               1516.35                1466.0   4.60  11.05
# 2023-11-21 11:15:00               1520.95                1466.0  -1.65   4.60
# 2023-11-21 12:15:00               1520.95                1466.0  -4.65  -1.65
# 2023-11-21 13:15:00               1520.95                1466.0   2.20  -4.65
# 2023-11-21 14:15:00               1520.95                1466.0   1.30   2.20
# 2023-11-21 15:15:00               1520.95                1467.4  -0.60   1.30
#
#                      ramp3  ramp4  ramp_close  ramp_volume   target
# datetime
# 2023-11-20 13:15:00   1.40  -0.95        0.05    1385906.0  1516.85
# 2023-11-20 14:15:00   0.10   1.40       -0.35    -287172.0  1518.15
# 2023-11-20 15:15:00   1.70   0.10        0.30    -601596.0  1517.55
# 2023-11-21 09:15:00  -0.20   1.70       12.90     976146.0      NaN
# 2023-11-21 10:15:00  -0.20  -0.20       18.45     750064.0      NaN
# 2023-11-21 11:15:00  11.05  -0.20       15.40     521276.0      NaN
# 2023-11-21 12:15:00   4.60  11.05       10.65     410834.0      NaN
# 2023-11-21 13:15:00  -1.65   4.60       11.15   -1540289.0      NaN
# 2023-11-21 14:15:00  -4.65  -1.65       12.65     646339.0      NaN
# 2023-11-21 15:15:00   2.20  -4.65       12.25     654439.0      NaN
#
# [10 rows x 63 columns]

# %%
data.columns
# Out:
# Index(['datetime', 'close', 'volume', 'date', 'hour', 'dom', 'month', 'year',
#        'dow', 'doy', 'woy', 'week_number', 'friday', 'cos_hour', 'sin_hour',
#        'cos_dow', 'sin_dow', 'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h',
#        'lag6h', 'lag12h', 'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d',
#        'lag7d', 'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h',
#        'mcp_dam_ewm4h', 'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h',
#        'mcp_dam_ewm24h', 'close_rolling_mean_4', 'close_rolling_max_4',
#        'close_rolling_min_4', 'close_rolling_mean_8', 'close_rolling_max_8',
#        'close_rolling_min_8', 'close_rolling_mean_12', 'close_rolling_max_12',
#        'close_rolling_min_12', 'close_rolling_mean_24', 'close_rolling_max_24',
#        'close_rolling_min_24', 'close_rolling_mean_48', 'close_rolling_max_48',
#        'close_rolling_min_48', 'close_rolling_mean_96', 'close_rolling_max_96',
#        'close_rolling_min_96', 'ramp1', 'ramp2', 'ramp3', 'ramp4',
#        'ramp_close', 'ramp_volume', 'target'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# datetime       0
# close          0
# volume         0
# date           0
# hour           0
#               ..
# ramp3          3
# ramp4          4
# ramp_close     7
# ramp_volume    7
# target         7
# Length: 64, dtype: int64

# %%
data.tail()
#data.head()
# Out:
#                  datetime    close     volume        date  hour  dom  month  \
# 12326 2023-11-21 11:15:00  1519.30  1313458.0  2023-11-21    12   21     11
# 12327 2023-11-21 12:15:00  1514.65  1469270.0  2023-11-21    13   21     11
# 12328 2023-11-21 13:15:00  1516.85   896454.0  2023-11-21    14   21     11
# 12329 2023-11-21 14:15:00  1518.15  2361418.0  2023-11-21    15   21     11
# 12330 2023-11-21 15:15:00  1517.55  1223239.0  2023-11-21    16   21     11
#
#        year  dow  doy  ...  close_rolling_mean_96  close_rolling_max_96  \
# 12326  2023    1  325  ...            1491.787500               1520.95
# 12327  2023    1  325  ...            1492.244271               1520.95
# 12328  2023    1  325  ...            1492.657292               1520.95
# 12329  2023    1  325  ...            1493.185938               1520.95
# 12330  2023    1  325  ...            1493.729167               1520.95
#
#        close_rolling_min_96  ramp1  ramp2  ramp3  ramp4  ramp_close  \
# 12326                1466.0  -1.65   4.60  11.05  -0.20       15.40
# 12327                1466.0  -4.65  -1.65   4.60  11.05       10.65
# 12328                1466.0   2.20  -4.65  -1.65   4.60       11.15
# 12329                1466.0   1.30   2.20  -4.65  -1.65       12.65
# 12330                1467.4  -0.60   1.30   2.20  -4.65       12.25
#
#        ramp_volume  target
# 12326     521276.0     NaN
# 12327     410834.0     NaN
# 12328   -1540289.0     NaN
# 12329     646339.0     NaN
# 12330     654439.0     NaN
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Dropping Missing Values

# %%
print(f'Before Dropping nans: {data_for_training.shape}')
data_for_training.dropna(inplace=True) # Dropping nans
data_for_training.reset_index(inplace=True) # Resetting index
print(data_for_training.shape)
data_for_training.tail(10)
# Out:
# Before Dropping nans: (12331, 63)
# (11652, 64)
#                  datetime    close     volume        date  hour  dom  month  \
# 11642 2023-11-17 13:15:00  1505.65  1050837.0  2023-11-17    14   17     11
# 11643 2023-11-17 14:15:00  1505.85  2002251.0  2023-11-17    15   17     11
# 11644 2023-11-17 15:15:00  1505.00  1170396.0  2023-11-17    16   17     11
# 11645 2023-11-20 09:15:00  1503.45  1819441.0  2023-11-20    10   20     11
# 11646 2023-11-20 10:15:00  1502.50   894623.0  2023-11-20    11   20     11
# 11647 2023-11-20 11:15:00  1503.90   792182.0  2023-11-20    12   20     11
# 11648 2023-11-20 12:15:00  1504.00  1058436.0  2023-11-20    13   20     11
# 11649 2023-11-20 13:15:00  1505.70  2436743.0  2023-11-20    14   20     11
# 11650 2023-11-20 14:15:00  1505.50  1715079.0  2023-11-20    15   20     11
# 11651 2023-11-20 15:15:00  1505.30   568800.0  2023-11-20    16   20     11
#
#        year  dow  doy  ...  close_rolling_mean_96  close_rolling_max_96  \
# 11642  2023    4  321  ...            1488.586458               1515.95
# 11643  2023    4  321  ...            1488.978125               1515.95
# 11644  2023    4  321  ...            1489.271354               1515.95
# 11645  2023    0  324  ...            1489.457292               1515.95
# 11646  2023    0  324  ...            1489.629688               1515.95
# 11647  2023    0  324  ...            1489.844271               1515.95
# 11648  2023    0  324  ...            1490.038542               1515.95
# 11649  2023    0  324  ...            1490.206771               1515.95
# 11650  2023    0  324  ...            1490.452083               1515.95
# 11651  2023    0  324  ...            1490.725521               1515.95
#
#        close_rolling_min_96  ramp1  ramp2  ramp3  ramp4  ramp_close  \
# 11642                1466.0  -0.15   2.15   1.25   2.15      -10.30
# 11643                1466.0   0.20  -0.15   2.15   1.25        0.60
# 11644                1466.0  -0.85   0.20  -0.15   2.15       -3.00
# 11645                1466.0  -1.55  -0.85   0.20  -0.15        3.20
# 11646                1466.0  -0.95  -1.55  -0.85   0.20        0.10
# 11647                1466.0   1.40  -0.95  -1.55  -0.85        0.25
# 11648                1466.0   0.10   1.40  -0.95  -1.55       -1.80
# 11649                1466.0   1.70   0.10   1.40  -0.95        0.05
# 11650                1466.0  -0.20   1.70   0.10   1.40       -0.35
# 11651                1466.0  -0.20  -0.20   1.70   0.10        0.30
#
#        ramp_volume   target
# 11642    -220054.0  1505.70
# 11643    -989669.0  1505.50
# 11644     -67750.0  1505.30
# 11645   -1814829.0  1516.35
# 11646    -543463.0  1520.95
# 11647    -269867.0  1519.30
# 11648      96793.0  1514.65
# 11649    1385906.0  1516.85
# 11650    -287172.0  1518.15
# 11651    -601596.0  1517.55
#
# [10 rows x 64 columns]

# %%
# Function to make feature extraction systematic

def diff(list1, list2):
    c = set(list1).union(set(list2))  # or c = set(list1) | set(list2)
    d = set(list1).intersection(set(list2))  # or d = set(list1) & set(list2)
    return list(c - d)

# %%
# Feature segregation

extra_features = ['weekend', 'date', 'year', 'target'] # Dont include 'datetime'
y_features = ['datetime', 'target']
X_features = [x for x in data_for_training.columns if x not in extra_features+['target']]


#print(X_features)
print(data_for_training[X_features].shape)
# Out:
# (11652, 61)

# %% [markdown]
# ## Train Test Split

# %%
## Experiments to check code

print(data_for_training['datetime'].max())

print(data_for_training['datetime'].max() - np.timedelta64(1, 'M'))

st_date = data_for_training['datetime'].max() - np.timedelta64(1, 'M')
f = dt.datetime(st_date.year, st_date.month, st_date.day, 9, 15)
print(f)
# Out:
# 2023-11-20 15:15:00
# 2023-10-21 04:45:54
# 2023-10-21 09:15:00

# %%
 #We have data from 2020-07-01 00:00:00
 #We have data till 2023-02-13 23:45:00

months_for_cutoff = 3

val_cut = data_for_training['datetime'].max() - np.timedelta64(4, 'M')
test_cut = data_for_training['datetime'].max() - np.timedelta64(1, 'M')

validation_cutoff = dt.datetime(val_cut.year, val_cut.month, val_cut.day, 15, 15)
test_cutoff = dt.datetime(test_cut.year, test_cut.month, test_cut.day, 15, 15)

print(f"X Train Date till: {validation_cutoff}")
print(f"X Validation Date till: {test_cutoff}")
#print(f"X Test Date: {}")
# Out:
# X Train Date till: 2023-07-21 15:15:00
# X Validation Date till: 2023-10-21 15:15:00

# %%
X = data_for_training[X_features].copy()
y = data_for_training[y_features].copy()
X.columns
# Out:
# Index(['datetime', 'close', 'volume', 'hour', 'dom', 'month', 'dow', 'doy',
#        'woy', 'week_number', 'friday', 'cos_hour', 'sin_hour', 'cos_dow',
#        'sin_dow', 'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h', 'lag6h',
#        'lag12h', 'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d', 'lag7d',
#        'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h', 'mcp_dam_ewm4h',
#        'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h', 'mcp_dam_ewm24h',
#        'close_rolling_mean_4', 'close_rolling_max_4', 'close_rolling_min_4',
#        'close_rolling_mean_8', 'close_rolling_max_8', 'close_rolling_min_8',
#        'close_rolling_mean_12', 'close_rolling_max_12', 'close_rolling_min_12',
#        'close_rolling_mean_24', 'close_rolling_max_24', 'close_rolling_min_24',
#        'close_rolling_mean_48', 'close_rolling_max_48', 'close_rolling_min_48',
#        'close_rolling_mean_96', 'close_rolling_max_96', 'close_rolling_min_96',
#        'ramp1', 'ramp2', 'ramp3', 'ramp4', 'ramp_close', 'ramp_volume'],
#       dtype='object')

# %% [markdown]
# ## VIF, it is taking too much of time and has not improved much accuracy

# %%
# # Define a function which computes VIF
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# def calculate_vif(df):
#     vif = pd.DataFrame()
#     vif['Feature'] = df.columns
#     vif['VIF'] = [variance_inflation_factor(df.values, i) for i in range(df.shape[1])]
#     return (vif)

# # Construct VIF dataframe

# #original_features = data_for_training.columns.tolist()
# original_features = X.drop('datetime', axis=1) # Delete datetime as it is not supported datatype
# #original_features = data.drop('diagnosis', axis = 1)

# vif_table = calculate_vif(original_features)
# vif_table = vif_table.sort_values(by = 'VIF', ascending = False, ignore_index = True)
# print(vif_table)

# features_to_drop = list(vif_table['Feature'])[:5]
# print(features_to_drop)


# As per extensive run, we have following features to remove
#features_to_drop = ['mcp_dam', 'lag1d_diff_sb_pb_dam', 'avg_mcp_dam_3d', 'avg_mcp_dam_2d', 'ramp4']


# features_to_drop = ['mcp_dam']
# X = X.drop(features_to_drop, axis = 1).copy()
# X.head()

# %%
def train_valid_test_split(X, y, validation_cutoff, test_cutoff):
    X_train = X[X['datetime'] <= validation_cutoff].iloc[:,1:].copy()
    y_train = y[y['datetime'] <= validation_cutoff].iloc[:,1:].copy()
    X_valid = X[(X['datetime'] > validation_cutoff) & (X['datetime'] <= test_cutoff)].iloc[:,1:].copy()
    y_valid = y[(y['datetime'] > validation_cutoff) & (y['datetime'] <= test_cutoff)].iloc[:,1:].copy()
    X_test = X[X['datetime'] > test_cutoff].iloc[:,1:].copy()
    y_test = y[y['datetime'] > test_cutoff].iloc[:,1:].copy()
    print(f'X Train: {X_train.shape}')
    print(f'X Validation: {X_valid.shape}')
    print(f'X Test: {X_test.shape}')
    print(f'y Train: {y_train.shape}')
    print(f'y Validation: {y_valid.shape}')
    print(f'y Test: {y_test.shape}')
    
    print("\n")
  
    X_train_date = X[X['datetime'] <= validation_cutoff].iloc[:,0:1].copy()
    X_valid_date = X[(X['datetime'] > validation_cutoff) & (X['datetime'] <= test_cutoff)].iloc[:,0:1].copy()
    X_test_date = X[X['datetime'] > test_cutoff].iloc[:,0:1].copy()
    print(f"X Train Date: {X_train_date['datetime'].max()}")
    print(f"X Validation Date: {X_valid_date['datetime'].max()}")
    print(f"X Test Date: {X_test_date['datetime'].max()}")

    return X_train, y_train, X_valid, y_valid, X_test, y_test

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(X, y, validation_cutoff, test_cutoff)
# Out:
# X Train: (11084, 60)
# X Validation: (434, 60)
# X Test: (134, 60)
# y Train: (11084, 1)
# y Validation: (434, 1)
# y Test: (134, 1)
#
#
# X Train Date: 2023-07-21 15:15:00
# X Validation Date: 2023-10-20 15:15:00
# X Test Date: 2023-11-20 15:15:00

# %%
X.columns
# Out:
# Index(['datetime', 'close', 'volume', 'hour', 'dom', 'month', 'dow', 'doy',
#        'woy', 'week_number', 'friday', 'cos_hour', 'sin_hour', 'cos_dow',
#        'sin_dow', 'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h', 'lag6h',
#        'lag12h', 'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d', 'lag7d',
#        'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h', 'mcp_dam_ewm4h',
#        'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h', 'mcp_dam_ewm24h',
#        'close_rolling_mean_4', 'close_rolling_max_4', 'close_rolling_min_4',
#        'close_rolling_mean_8', 'close_rolling_max_8', 'close_rolling_min_8',
#        'close_rolling_mean_12', 'close_rolling_max_12', 'close_rolling_min_12',
#        'close_rolling_mean_24', 'close_rolling_max_24', 'close_rolling_min_24',
#        'close_rolling_mean_48', 'close_rolling_max_48', 'close_rolling_min_48',
#        'close_rolling_mean_96', 'close_rolling_max_96', 'close_rolling_min_96',
#        'ramp1', 'ramp2', 'ramp3', 'ramp4', 'ramp_close', 'ramp_volume'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['close', 'volume', 'hour', 'dom', 'month', 'dow', 'doy', 'woy',
#        'week_number', 'friday', 'cos_hour', 'sin_hour', 'cos_dow', 'sin_dow',
#        'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h', 'lag6h', 'lag12h',
#        'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d', 'lag7d',
#        'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h', 'mcp_dam_ewm4h',
#        'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h', 'mcp_dam_ewm24h',
#        'close_rolling_mean_4', 'close_rolling_max_4', 'close_rolling_min_4',
#        'close_rolling_mean_8', 'close_rolling_max_8', 'close_rolling_min_8',
#        'close_rolling_mean_12', 'close_rolling_max_12', 'close_rolling_min_12',
#        'close_rolling_mean_24', 'close_rolling_max_24', 'close_rolling_min_24',
#        'close_rolling_mean_48', 'close_rolling_max_48', 'close_rolling_min_48',
#        'close_rolling_mean_96', 'close_rolling_max_96', 'close_rolling_min_96',
#        'ramp1', 'ramp2', 'ramp3', 'ramp4', 'ramp_close', 'ramp_volume'],
#       dtype='object')

# %% [markdown]
# # Mode-1 (XGBoost)

# %%
### Feature Selection


# XGBoost
import xgboost as xgb
xgb_model = xgb.XGBRegressor(
    #tree_method = "gpu_hist", # To use GPU
    booster='gbtree',
    objective='reg:squarederror',
    n_estimators=1000,
    max_depth=10,
    learning_rate=0.1,
    gamma=0,alpha=0,
    seed=2
)


# Here we are not using scaled features as its not required for xgbboost reg
eval_set = [(X_train, y_train), (X_valid, y_valid)]
xgb_model.fit(X_train, y_train, early_stopping_rounds=30, eval_metric="mae", eval_set=eval_set, verbose=False)
#xgb_model.fit(X_train, y_train, eval_metric="mae", eval_set=eval_set, verbose=200)
# Out:
# XGBRegressor(alpha=0, base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=10, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              predictor=None, ...)

# %%
results = xgb_model.evals_result()

plt.figure(figsize=(6,4))
plt.plot(results["validation_0"]["mae"], label="Training loss")
plt.plot(results["validation_1"]["mae"], label="Validation loss")
#plt.axvline(xgb_model.best_ntree_limit, color="gray", label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()
#print(f'No of Optimum Tress = {xgb_model.best_ntree_limit}')

# %%
print(f'No of Optimum Tress = {xgb_model.best_ntree_limit}')
# Out:
# No of Optimum Tress = 108

# %%
feature_names= X_train.columns.tolist()
xgb_features = pd.DataFrame({'feature_names': feature_names, 
                             'feature_importance': xgb_model.feature_importances_}).sort_values(by=['feature_importance'], ascending=False).reset_index(drop=True)
xgb_features
# Out:
#             feature_names  feature_importance
# 0           mcp_dam_ewm2h            0.373370
# 1     close_rolling_max_8            0.269375
# 2           mcp_dam_ewm1h            0.078779
# 3     close_rolling_max_4            0.072497
# 4    close_rolling_max_12            0.060657
# 5                   close            0.039245
# 6     close_rolling_min_4            0.029577
# 7     close_rolling_min_8            0.022729
# 8    close_rolling_max_24            0.020398
# 9    close_rolling_min_24            0.014550
# 10   close_rolling_max_96            0.004686
# 11  close_rolling_mean_48            0.002843
# 12   close_rolling_max_48            0.002603
# 13          mcp_dam_ewm3h            0.002200
# 14          mcp_dam_ewm8h            0.001159
# 15  close_rolling_mean_12            0.001080
# 16   close_rolling_min_12            0.000947
# 17         mcp_dam_ewm12h            0.000699
# 18   close_rolling_min_48            0.000484
# 19  close_rolling_mean_24            0.000271
# 20         mcp_dam_ewm24h            0.000258
# 21          mcp_dam_ewm6h            0.000160
# 22                  lag4d            0.000113
# 23                    woy            0.000100
# 24                  lag6h            0.000099
# 25                  lag2d            0.000096
# 26                  lag4h            0.000091
# 27                sin_doy            0.000081
# 28   close_rolling_min_96            0.000073
# 29                    doy            0.000063
# 30                  lag7d            0.000058
# 31  close_rolling_mean_96            0.000056
# 32                  lag3d            0.000050
# 33                sin_dow            0.000048
# 34                    dom            0.000045
# 35                cos_doy            0.000044
# 36                  lag6d            0.000044
# 37          mcp_dam_ewm4h            0.000042
# 38                  lag5d            0.000042
# 39                 lag12h            0.000041
# 40                    dow            0.000039
# 41                cos_dow            0.000032
# 42   close_rolling_mean_8            0.000030
# 43                  lag1d            0.000029
# 44             ramp_close            0.000021
# 45                  month            0.000018
# 46   close_rolling_mean_4            0.000017
# 47                  lag2h            0.000014
# 48            ramp_volume            0.000009
# 49                  ramp1            0.000007
# 50                  lag1h            0.000007
# 51                  ramp2            0.000005
# 52                  ramp4            0.000005
# 53                  ramp3            0.000004
# 54                 volume            0.000003
# 55                   hour            0.000003
# 56               cos_hour            0.000002
# 57                 friday            0.000002
# 58               sin_hour            0.000002
# 59            week_number            0.000000

# %%
best_features = xgb_features[xgb_features['feature_importance']>=0.005]['feature_names'].tolist()
best_features
# Out:
# ['mcp_dam_ewm2h',
#  'close_rolling_max_8',
#  'mcp_dam_ewm1h',
#  'close_rolling_max_4',
#  'close_rolling_max_12',
#  'close',
#  'close_rolling_min_4',
#  'close_rolling_min_8',
#  'close_rolling_max_24',
#  'close_rolling_min_24']

# %%
#xgb_features.to_csv('features.csv', index=False) # Storing important features for analyzing

# %% [markdown]
# ## Check all Best Features

# %%
sns.heatmap(data[best_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
#sns.pairplot(data[best_features]) #later

# %% [markdown]
# ## Hyperparameter Tuning with Optuna

# %%
#pip install optuna

# %%
import xgboost as xgb
import optuna
from sklearn.metrics import mean_squared_error

def objective(trial):
    # Hyper Parameters
    param = {
        "booster": trial.suggest_categorical("booster", ["gbtree"]),
        "lambda": trial.suggest_int("lambda", 0, 100, step=10),
        "alpha": trial.suggest_int("alpha", 0, 100, step=10),
        "gamma": trial.suggest_float("gamma", 1e-8, 1.0, log=True),
        "subsample": trial.suggest_float("subsample", 0.8, 0.9),
        "min_child_weight": trial.suggest_int("min_child_weight", 2, 10),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.8, 0.9),
        "max_leaves": trial.suggest_int("max_leaves", 1000, 2000,step=20),
        'max_depth': trial.suggest_int('max_depth', 10, 15),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        #"grow_policy": trial.suggest_categorical("grow_policy", ["depthwise", "lossguide"])
    }
    
    model = xgb.XGBRegressor(
        objective='reg:squarederror',
        #tree_method = "gpu_hist", # To use GPU
        n_estimators=2000,
        **param
        )
    model.fit(X_train[best_features],y_train,eval_set=[(X_valid[best_features],y_valid)],eval_metric='rmse',early_stopping_rounds=100,verbose=100)
    preds = model.predict(X_valid[best_features])
    error = mean_squared_error(y_valid, preds)
    return error
 
study = optuna.create_study(direction='minimize',study_name="XGB")
study.optimize(objective, n_trials=10) # We can increase n_trials to check more combinations, later increse
 
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2023-11-22 18:37:31,938] A new study created in memory with name: XGB
# [0]	validation_0-rmse:1566.25182
# [100]	validation_0-rmse:397.01433
# [200]	validation_0-rmse:100.10437
# [300]	validation_0-rmse:29.37954
# [400]	validation_0-rmse:17.86274
# [500]	validation_0-rmse:17.16097
# [581]	validation_0-rmse:17.37115
# [I 2023-11-22 18:37:42,086] Trial 0 finished with value: 293.22796265956566 and parameters: {'booster': 'gbtree', 'lambda': 70, 'alpha': 40, 'gamma': 0.017122229976598437, 'subsample': 0.8767302192162514, 'min_child_weight': 9, 'colsample_bytree': 0.8348780844318946, 'max_leaves': 1080, 'max_depth': 15, 'learning_rate': 0.014779890741734776}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1219.17662
# [100]	validation_0-rmse:19.43240
# [129]	validation_0-rmse:19.43890
# [I 2023-11-22 18:37:45,692] Trial 1 finished with value: 321.0552132263696 and parameters: {'booster': 'gbtree', 'lambda': 70, 'alpha': 60, 'gamma': 1.1429738523436533e-08, 'subsample': 0.8910007618687589, 'min_child_weight': 10, 'colsample_bytree': 0.8592434852874306, 'max_leaves': 1860, 'max_depth': 12, 'learning_rate': 0.2546813875330838}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1419.77213
# [100]	validation_0-rmse:17.88479
# [160]	validation_0-rmse:18.56207
# [I 2023-11-22 18:37:49,713] Trial 2 finished with value: 299.055991339373 and parameters: {'booster': 'gbtree', 'lambda': 40, 'alpha': 20, 'gamma': 0.00014267463369329122, 'subsample': 0.8651583079668264, 'min_child_weight': 6, 'colsample_bytree': 0.8696222763326951, 'max_leaves': 1180, 'max_depth': 13, 'learning_rate': 0.11422890800509894}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1186.59447
# [100]	validation_0-rmse:19.72636
# [120]	validation_0-rmse:19.80330
# [I 2023-11-22 18:37:52,767] Trial 3 finished with value: 328.8636549179646 and parameters: {'booster': 'gbtree', 'lambda': 40, 'alpha': 40, 'gamma': 0.04855749223552099, 'subsample': 0.8624937548616892, 'min_child_weight': 5, 'colsample_bytree': 0.8275670958121861, 'max_leaves': 1220, 'max_depth': 13, 'learning_rate': 0.2729496845083094}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1417.36332
# [100]	validation_0-rmse:18.09002
# [154]	validation_0-rmse:18.41968
# [I 2023-11-22 18:37:56,000] Trial 4 finished with value: 298.30097468109983 and parameters: {'booster': 'gbtree', 'lambda': 20, 'alpha': 100, 'gamma': 1.6411338004029183e-08, 'subsample': 0.8714811690550992, 'min_child_weight': 8, 'colsample_bytree': 0.8196205201365397, 'max_leaves': 1740, 'max_depth': 12, 'learning_rate': 0.11434655247639507}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1407.64932
# [100]	validation_0-rmse:18.33912
# [151]	validation_0-rmse:18.72823
# [I 2023-11-22 18:37:59,571] Trial 5 finished with value: 314.6754806034561 and parameters: {'booster': 'gbtree', 'lambda': 40, 'alpha': 60, 'gamma': 0.6870980653166873, 'subsample': 0.876548468911257, 'min_child_weight': 4, 'colsample_bytree': 0.8377365949121444, 'max_leaves': 1140, 'max_depth': 13, 'learning_rate': 0.12246683805968281}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1171.57091
# [100]	validation_0-rmse:19.27986
# [127]	validation_0-rmse:19.49172
# [I 2023-11-22 18:38:03,172] Trial 6 finished with value: 309.11801223927085 and parameters: {'booster': 'gbtree', 'lambda': 100, 'alpha': 50, 'gamma': 1.8096757981851727e-05, 'subsample': 0.8884838395325694, 'min_child_weight': 4, 'colsample_bytree': 0.8566005238904967, 'max_leaves': 1800, 'max_depth': 14, 'learning_rate': 0.29135099069513054}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1315.91308
# [100]	validation_0-rmse:18.17244
# [139]	validation_0-rmse:18.53645
# [I 2023-11-22 18:38:06,373] Trial 7 finished with value: 316.89063596086686 and parameters: {'booster': 'gbtree', 'lambda': 100, 'alpha': 50, 'gamma': 0.1441058143149674, 'subsample': 0.8431056084082342, 'min_child_weight': 3, 'colsample_bytree': 0.803398880855639, 'max_leaves': 1520, 'max_depth': 12, 'learning_rate': 0.19041920101097662}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1444.20065
# [100]	validation_0-rmse:17.70346
# [166]	validation_0-rmse:18.10771
# [I 2023-11-22 18:38:09,747] Trial 8 finished with value: 303.43793328503847 and parameters: {'booster': 'gbtree', 'lambda': 100, 'alpha': 70, 'gamma': 0.17562263947325582, 'subsample': 0.8773954530740852, 'min_child_weight': 8, 'colsample_bytree': 0.8788559754567793, 'max_leaves': 1320, 'max_depth': 12, 'learning_rate': 0.10043829177721182}. Best is trial 0 with value: 293.22796265956566.
# [0]	validation_0-rmse:1532.51755
# [100]	validation_0-rmse:42.47272
# [200]	validation_0-rmse:17.23619
# [272]	validation_0-rmse:17.63728
# [I 2023-11-22 18:38:15,130] Trial 9 finished with value: 293.44248852262695 and parameters: {'booster': 'gbtree', 'lambda': 40, 'alpha': 0, 'gamma': 2.4621153404512113e-05, 'subsample': 0.8366765223920698, 'min_child_weight': 8, 'colsample_bytree': 0.8360373097920456, 'max_leaves': 1680, 'max_depth': 15, 'learning_rate': 0.037520678932043}. Best is trial 0 with value: 293.22796265956566.
# Number of finished trials: 10
# Best trial: {'booster': 'gbtree', 'lambda': 70, 'alpha': 40, 'gamma': 0.017122229976598437, 'subsample': 0.8767302192162514, 'min_child_weight': 9, 'colsample_bytree': 0.8348780844318946, 'max_leaves': 1080, 'max_depth': 15, 'learning_rate': 0.014779890741734776}

# %%
study.best_params
# Out:
# {'booster': 'gbtree',
#  'lambda': 70,
#  'alpha': 40,
#  'gamma': 0.017122229976598437,
#  'subsample': 0.8767302192162514,
#  'min_child_weight': 9,
#  'colsample_bytree': 0.8348780844318946,
#  'max_leaves': 1080,
#  'max_depth': 15,
#  'learning_rate': 0.014779890741734776}

# %%
param = study.best_params
xgbreg = xgb.XGBRegressor(
    objective='reg:squarederror',
    #tree_method = "gpu_hist", # To use GPU
    n_estimators=1000,    
    **param
    )
xgbreg.fit(X_train[best_features],y_train,eval_set=[(X_valid[best_features],y_valid)],eval_metric='rmse',early_stopping_rounds=20,verbose=100)
# Out:
# [0]	validation_0-rmse:1566.25182
# [100]	validation_0-rmse:397.01433
# [200]	validation_0-rmse:100.10437
# [300]	validation_0-rmse:29.37954
# [400]	validation_0-rmse:17.86274
# [500]	validation_0-rmse:17.16097
# XGBRegressor(alpha=40, base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8348780844318946, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.017122229976598437, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None, lambda=70,
#              learning_rate=0.014779890741734776, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=15, max_leaves=1080,
#              min_child_weight=9, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None, ...)

# %%
# Making predictions with the tuned model
pred_train = xgbreg.predict(X_train[best_features])
pred_valid = xgbreg.predict(X_valid[best_features])
pred_test = xgbreg.predict(X_test[best_features])

# %%
# Evaluate model accuracy 
from sklearn.metrics import mean_squared_error
print(f"Train MSE: {mean_squared_error(y_train['target'],pred_train)}")
print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train['target'],pred_train))}")
print(f"valid MSE: {mean_squared_error(y_valid['target'],pred_valid)}")
print(f"valid RMSE: {np.sqrt(mean_squared_error(y_valid['target'],pred_valid))}")
print(f"Test MSE: {mean_squared_error(y_test['target'],pred_test)}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test['target'],pred_test))}")
# Out:
# Train MSE: 246.35827501603436
# Train RMSE: 15.695804376203036
# valid MSE: 293.22796265956566
# valid RMSE: 17.12390033431536
# Test MSE: 143.13557057217852
# Test RMSE: 11.963927890629336

# %%
result = y[y['datetime'] > test_cutoff].copy()
result['prediction_xgb'] = pred_test
result.tail(10)
# Out:
#                  datetime   target  prediction_xgb
# 11642 2023-11-17 13:15:00  1505.70     1512.672729
# 11643 2023-11-17 14:15:00  1505.50     1511.735107
# 11644 2023-11-17 15:15:00  1505.30     1511.521240
# 11645 2023-11-20 09:15:00  1516.35     1511.064087
# 11646 2023-11-20 10:15:00  1520.95     1509.525879
# 11647 2023-11-20 11:15:00  1519.30     1506.808838
# 11648 2023-11-20 12:15:00  1514.65     1502.814819
# 11649 2023-11-20 13:15:00  1516.85     1503.222900
# 11650 2023-11-20 14:15:00  1518.15     1503.178955
# 11651 2023-11-20 15:15:00  1517.55     1503.178955

# %%
result_train = y[(y['datetime'] <= validation_cutoff)].copy()
result_train['prediction_xgb'] = pred_train
plt.figure(figsize=(10,5))
result_train.set_index('datetime').plot()
plt.title(f"Prediction for TRAIN DATA")
# Out:
# Text(0.5, 1.0, 'Prediction for TRAIN DATA')

# %%
 #We have data from 2020-07-01 00:00:00
 #We have data till 2023-02-13 23:45:00

result_valid = y[(y['datetime'] > validation_cutoff) & (y['datetime'] <= test_cutoff)].copy()
result_valid['prediction_xgb'] = pred_valid
plt.figure(figsize=(10,5))
result_valid.set_index('datetime').plot()
plt.title(f"Prediction for VALIDATION DATA")
# Out:
# Text(0.5, 1.0, 'Prediction for VALIDATION DATA')

# %%
mask = (result.datetime > test_cutoff)
result.loc[mask,:].set_index('datetime')
result.loc[mask,:].set_index('datetime').plot()
plt.title("Prediction for TEST")

#result.loc[mask,:].set_index('datetime')
# Out:
# Text(0.5, 1.0, 'Prediction for TEST')

# %%
from datetime import datetime, timedelta

holiday_list = ['2023-11-27', '2023-12-25']
#holiday_list = [x+' 00:00:00' for x in holiday_list]
#holiday_list = [datetime.strptime(x, '%Y-%m-%d') for x in holiday_list]


def find_last_working_day(test_date):
    
    if test_date.weekday() == 0:
        diff = 3
    elif test_date.weekday() == 6:
        diff = 2
    else :
        diff = 1

    res = test_date - timedelta(days=diff)
    
    while str(res) in holiday_list:
        res = res - timedelta(days=1)
    
    print(f"Input Date:{test_date} ~~~~ Last Working date:{str(res)}")
        
    return res

#test_date = datetime(2023, 11, 16)
test_date = dt.date.today()


last_working = find_last_working_day(test_date)
# Out:
# Input Date:2023-11-22 ~~~~ Last Working date:2023-11-21

# %%
# result.datetime.to_numpy()[0] > dt.date.today()

# %%
#(result.datetime > pd.Timestamp.today())
#result.datetime > np.datetime64('today', 'D')

# %%
# ajj = dt.date.today()
# #ajj = np.datetime64('today', 'D')
# end_date = find_last_working_day(ajj)
# np.datetime64(end_date)

# %%
ajj = dt.date.today() # I guess its in python only
#ajj = np.datetime64('today', 'D') # How we define in numpy
#ajj = pd.Timestamp.today()  # How we define in pandas

end_date = find_last_working_day(ajj)


#----- to run code for Saturday and Sunday------------------
if ajj.weekday() == 5:
    ajj = ajj - timedelta(days=1)
    end_date = end_date - timedelta(days=1)

if ajj.weekday() == 6:
    ajj = ajj - timedelta(days=2)
    end_date = end_date - timedelta(days=2)
#----- End of to run code for Saturday and Sunday------------------
    
    

print(f"Forcast for: {ajj}")
mask = (result.datetime > np.datetime64(end_date))
#mask = (result.datetime >= end_date)

result.loc[mask,:].set_index('datetime').plot()
plt.title("Prediction for Today")

result.loc[mask,:].set_index('datetime')
# Out:
# Input Date:2023-11-22 ~~~~ Last Working date:2023-11-21
# Forcast for: 2023-11-22
# Empty DataFrame
# Columns: [target, prediction_xgb]
# Index: []

# %%
# # JUST ANOTHER WAY FOR ABOVE CODE

# end_date = dt.date.today()
# days_sub = 1 # XXXXXXXXXXXXXXXXXXXXXXX
# end_date = dt.datetime(end_date.year, end_date.month, end_date.day-days_sub, 9, 15)

# print(f"Forcast Date~~~~~{end_date}")

# mask = (result.datetime >= end_date)
# result.loc[mask,:].set_index('datetime').plot()
# plt.title("Prediction for Today")


# result.loc[mask,:].set_index('datetime')

# %%
def feature_importance(features, importance_score):
    importances = pd.DataFrame(data={
        'Attribute': features,
        'Importance': importance_score
    })
    importances = importances.sort_values(by='Importance', ascending=False)
    plt.bar(x=importances['Attribute'], height=importances['Importance'])
    plt.title('Feature importances obtained from coefficients')
    plt.xticks(rotation='vertical')
    plt.show()

# %%
print(X_train.columns.shape)
print(xgbreg.feature_importances_.shape)
# Out:
# (60,)
# (10,)

# %%
feature_importance(best_features, xgbreg.feature_importances_)

# %% [markdown]
# ## Final Model saving

# %%
# Saving the final Best features used by model
model_name = f"{stock}_best_features_XGBoost"
pickle.dump(best_features, open(f'03_Saved_Model/{model_name}.pkl', 'wb'))

# %%
# Saving the final model
model_name = f"{stock}_XGBoost"
pickle.dump(xgbreg, open(f'03_Saved_Model/{model_name}.pkl', 'wb'))

# %% [markdown]
# # Model-2 - Logistic Regression

# %%
#We Have the following:
#X_train, y_train, X_valid, y_valid, X_test, y_test = train_valid_test_split(X, y, validation_cutoff, test_cutoff)

# %% [markdown]
# ### Multicollinearity check by VIF score

# %%
# """
# Let's now keep on removing features till we have a feature with vif<5
# """
# import statsmodels.api as sm

# scaler_vif = StandardScaler()
# X_train_vif_s = scaler_vif.fit_transform(X_train)





# vif_thr = 20
# #r2_thr = 0.85
# i = 0
# feats_removed = []

# cols2=X.columns

# while True:
    
#     vif = pd.DataFrame()
#     X_t = pd.DataFrame(X_train_vif_s, columns=X.columns)[cols2]
#     vif['Features'] = cols2
#     vif['VIF'] = [variance_inflation_factor(X_t.values, i) for i in range(X_t.shape[1])]
#     vif['VIF'] = round(vif['VIF'], 2)
#     vif = vif.sort_values(by = "VIF", ascending = False)

#   #cols2 = vif["Features"][1:].values
#     cols2 = vif["Features"][i:].values
#     X2 = pd.DataFrame(X_train_vif_s, columns=X.columns)[cols2]

#     #X2_sm = sm.add_constant(X2)  #Statmodels default is without intercept, to add intercept we need to add constant
#     #sm_model = sm.OLS(list(y_train), X2_sm).fit()
  
#     print('Feature no. ', i)
#     print('VIF Score ', vif.iloc[i]['VIF'])
#     #print('Adjusted R2 ', sm_model.rsquared_adj)


#     #if (vif.iloc[i]['VIF'] < vif_thr) or (sm_model.rsquared_adj > r2_thr):
#     if (vif.iloc[i]['VIF'] < vif_thr):
#         print('Reached threshold')
#         print('Highest vif:',vif.iloc[i])
#         #print('Current adj.R2',sm_model.rsquared_adj)
#         print('Features removed:', i)
#         print('List of features removed:', feats_removed)
#         break
#     feats_removed.append(vif.iloc[i]['Features'])
#     i += 1

# %%
11638-(11056+441+141)
# Out:
# 0

# %% [markdown]
# ## Scaling

# %%
# rescale the features
#scaler = MinMaxScaler()
scaler = StandardScaler()
#scaler = RobustScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_valid_scaled = scaler.transform(X_valid) # Transform to Validation data as well
X_test_scaled = scaler.transform(X_test) # Transform to test data as well

# %%
print('Train =', X_train_scaled.shape, y_train.shape)
print('Train =', X_valid_scaled.shape, y_valid.shape)
print('Test =', X_test_scaled.shape, y_test.shape)
# Out:
# Train = (11084, 60) (11084, 1)
# Train = (434, 60) (434, 1)
# Test = (134, 60) (134, 1)

# %%
# ['close', 'volume', 'hour', 'dom', 'month', 'dow', 'doy', 'woy',
#        'week_number', 'friday', 'cos_hour', 'sin_hour', 'cos_dow', 'sin_dow',
#        'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h', 'lag6h', 'lag12h',
#        'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d', 'lag7d',
#        'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h', 'mcp_dam_ewm4h',
#        'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h', 'mcp_dam_ewm24h',
#        'close_rolling_mean_4', 'close_rolling_max_4', 'close_rolling_min_4',
#        'close_rolling_mean_8', 'close_rolling_max_8', 'close_rolling_min_8',
#        'close_rolling_mean_12', 'close_rolling_max_12', 'close_rolling_min_12',
#        'close_rolling_mean_24', 'close_rolling_max_24', 'close_rolling_min_24',
#        'close_rolling_mean_48', 'close_rolling_max_48', 'close_rolling_min_48',
#        'close_rolling_mean_96', 'close_rolling_max_96', 'close_rolling_min_96',
#        'ramp1', 'ramp2', 'ramp3', 'ramp4', 'ramp_close', 'ramp_volume']

# %%
X_train.columns
# Out:
# Index(['close', 'volume', 'hour', 'dom', 'month', 'dow', 'doy', 'woy',
#        'week_number', 'friday', 'cos_hour', 'sin_hour', 'cos_dow', 'sin_dow',
#        'cos_doy', 'sin_doy', 'lag1h', 'lag2h', 'lag4h', 'lag6h', 'lag12h',
#        'lag1d', 'lag2d', 'lag3d', 'lag4d', 'lag5d', 'lag6d', 'lag7d',
#        'mcp_dam_ewm1h', 'mcp_dam_ewm2h', 'mcp_dam_ewm3h', 'mcp_dam_ewm4h',
#        'mcp_dam_ewm6h', 'mcp_dam_ewm8h', 'mcp_dam_ewm12h', 'mcp_dam_ewm24h',
#        'close_rolling_mean_4', 'close_rolling_max_4', 'close_rolling_min_4',
#        'close_rolling_mean_8', 'close_rolling_max_8', 'close_rolling_min_8',
#        'close_rolling_mean_12', 'close_rolling_max_12', 'close_rolling_min_12',
#        'close_rolling_mean_24', 'close_rolling_max_24', 'close_rolling_min_24',
#        'close_rolling_mean_48', 'close_rolling_max_48', 'close_rolling_min_48',
#        'close_rolling_mean_96', 'close_rolling_max_96', 'close_rolling_min_96',
#        'ramp1', 'ramp2', 'ramp3', 'ramp4', 'ramp_close', 'ramp_volume'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

reg_model = LinearRegression(n_jobs=-1)
reg_model.fit(X_train_scaled, y_train)

# Make predictions using the testing set
y_train_pred = reg_model.predict(X_train_scaled)
X_valid_pred = reg_model.predict(X_valid_scaled)
y_test_pred = reg_model.predict(X_test_scaled)

# %%
# Making predictions with the tuned model
pred_train = reg_model.predict(X_train_scaled)
pred_valid = reg_model.predict(X_valid_scaled)
pred_test = reg_model.predict(X_test_scaled)

# %%
# Evaluate model accuracy 
from sklearn.metrics import mean_squared_error
print(f"Train MSE: {mean_squared_error(y_train['target'],pred_train)}")
print(f"Train RMSE: {np.sqrt(mean_squared_error(y_train['target'],pred_train))}")
print(f"valid MSE: {mean_squared_error(y_valid['target'],pred_valid)}")
print(f"valid RMSE: {np.sqrt(mean_squared_error(y_valid['target'],pred_valid))}")
print(f"Test MSE: {mean_squared_error(y_test['target'],pred_test)}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test['target'],pred_test))}")
# Out:
# Train MSE: 357.10925154033305
# Train RMSE: 18.8973345088754
# valid MSE: 265.77393462971565
# valid RMSE: 16.302574478582077
# Test MSE: 157.6006825685144
# Test RMSE: 12.553911046702314

# %%
#result = y[y['datetime'] > test_cutoff].copy()
result['prediction_LR'] = pred_test
result.tail(10)
# Out:
#                  datetime   target  prediction_xgb  prediction_LR
# 11642 2023-11-17 13:15:00  1505.70     1512.672729    1508.645380
# 11643 2023-11-17 14:15:00  1505.50     1511.735107    1509.789049
# 11644 2023-11-17 15:15:00  1505.30     1511.521240    1507.560309
# 11645 2023-11-20 09:15:00  1516.35     1511.064087    1507.378952
# 11646 2023-11-20 10:15:00  1520.95     1509.525879    1506.361238
# 11647 2023-11-20 11:15:00  1519.30     1506.808838    1508.451187
# 11648 2023-11-20 12:15:00  1514.65     1502.814819    1508.365916
# 11649 2023-11-20 13:15:00  1516.85     1503.222900    1509.452067
# 11650 2023-11-20 14:15:00  1518.15     1503.178955    1510.186134
# 11651 2023-11-20 15:15:00  1517.55     1503.178955    1510.197776

# %%
result_train = y[(y['datetime'] <= validation_cutoff)].copy()
result_train['prediction_LR'] = pred_train
plt.figure(figsize=(10,5))
result_train.set_index('datetime').plot()
plt.title(f"Prediction for TRAIN DATA")
# Out:
# Text(0.5, 1.0, 'Prediction for TRAIN DATA')

# %%
result_valid = y[(y['datetime'] > validation_cutoff) & (y['datetime'] <= test_cutoff)].copy()
result_valid['prediction_LR'] = pred_valid
plt.figure(figsize=(10,5))
result_valid.set_index('datetime').plot()
plt.title(f"Prediction for VALIDATION DATA")
# Out:
# Text(0.5, 1.0, 'Prediction for VALIDATION DATA')

# %%
mask = (result.datetime > test_cutoff)
result.loc[mask,:].set_index('datetime')
result.loc[mask,:].set_index('datetime').plot()
plt.title("Prediction for TEST")
# Out:
# Text(0.5, 1.0, 'Prediction for TEST')

# %%
print(f"Forcast for: {ajj}")
mask = (result.datetime > np.datetime64(end_date))
#mask = (result.datetime >= end_date)

result.loc[mask,:].set_index('datetime').plot()
plt.title("Prediction for Today")

result.loc[mask,:].set_index('datetime')
# Out:
# Forcast for: 2023-11-22
# Empty DataFrame
# Columns: [target, prediction_xgb, prediction_LR]
# Index: []

# %% [markdown]
# ## Feature Importance checking

# %%
feature_importance(X_train.columns, reg_model.coef_[0])

# %% [markdown]
# ## Final Model saving

# %%
# Saving the final scaler model
model_name = f"{stock}_scaler_LR"
pickle.dump(scaler, open(f'03_Saved_Model/{model_name}.pkl', 'wb'))

# %%
# Saving the final model
model_name = f"{stock}_LR"
pickle.dump(reg_model, open(f'03_Saved_Model/{model_name}.pkl', 'wb'))

# %%
print("All done and push a little more for more accuracy")
# Out:
# All done and push a little more for more accuracy
